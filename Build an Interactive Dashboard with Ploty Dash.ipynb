# %%
# !pip install dash
# !pip install dash==1.19.0
# !pip install jupyter_dash
# !pip install --upgrade plotly
# Out:
# Requirement already satisfied: dash in c:\users\win\venv\lib\site-packages (2.6.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\win\venv\lib\site-packages (from dash) (5.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\win\venv\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\win\venv\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: Flask>=1.0.4 in c:\users\win\venv\lib\site-packages (from dash) (2.1.2)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\win\venv\lib\site-packages (from dash) (5.9.0)
# Requirement already satisfied: flask-compress in c:\users\win\venv\lib\site-packages (from dash) (1.12)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\win\venv\lib\site-packages (from Flask>=1.0.4->dash) (2.1.2)
# Requirement already satisfied: Werkzeug>=2.0 in c:\users\win\venv\lib\site-packages (from Flask>=1.0.4->dash) (2.0.3)
# Requirement already satisfied: click>=8.0 in c:\users\win\venv\lib\site-packages (from Flask>=1.0.4->dash) (8.1.3)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\win\venv\lib\site-packages (from Flask>=1.0.4->dash) (3.1.2)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\win\venv\lib\site-packages (from plotly>=5.0.0->dash) (8.0.1)
# Requirement already satisfied: brotli in c:\users\win\venv\lib\site-packages (from flask-compress->dash) (1.0.9)
# Requirement already satisfied: colorama in c:\users\win\venv\lib\site-packages (from click>=8.0->Flask>=1.0.4->dash) (0.4.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\win\venv\lib\site-packages (from Jinja2>=3.0->Flask>=1.0.4->dash) (2.1.1)
# WARNING: You are using pip version 21.3.1; however, version 22.2 is available.
# You should consider upgrading via the 'C:\Users\Win\venv\Scripts\python.exe -m pip install --upgrade pip' command.
# Collecting dash==1.19.0
#   Using cached dash-1.19.0-py3-none-any.whl
# Requirement already satisfied: flask-compress in c:\users\win\venv\lib\site-packages (from dash==1.19.0) (1.12)
# Requirement already satisfied: dash-renderer==1.9.0 in c:\users\win\venv\lib\site-packages (from dash==1.19.0) (1.9.0)
# Requirement already satisfied: Flask>=1.0.4 in c:\users\win\venv\lib\site-packages (from dash==1.19.0) (2.1.2)
# Requirement already satisfied: plotly in c:\users\win\venv\lib\site-packages (from dash==1.19.0) (5.9.0)
# Collecting dash-html-components==1.1.2
#   Using cached dash_html_components-1.1.2-py3-none-any.whl
# Collecting dash-table==4.11.2
#   Using cached dash_table-4.11.2-py3-none-any.whl
# Collecting dash-core-components==1.15.0
#   Using cached dash_core_components-1.15.0-py3-none-any.whl
# Requirement already satisfied: future in c:\users\win\venv\lib\site-packages (from dash==1.19.0) (0.18.2)
# Requirement already satisfied: click>=8.0 in c:\users\win\venv\lib\site-packages (from Flask>=1.0.4->dash==1.19.0) (8.1.3)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\win\venv\lib\site-packages (from Flask>=1.0.4->dash==1.19.0) (2.1.2)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\win\venv\lib\site-packages (from Flask>=1.0.4->dash==1.19.0) (3.1.2)
# Requirement already satisfied: Werkzeug>=2.0 in c:\users\win\venv\lib\site-packages (from Flask>=1.0.4->dash==1.19.0) (2.0.3)
# Requirement already satisfied: brotli in c:\users\win\venv\lib\site-packages (from flask-compress->dash==1.19.0) (1.0.9)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\win\venv\lib\site-packages (from plotly->dash==1.19.0) (8.0.1)
# Requirement already satisfied: colorama in c:\users\win\venv\lib\site-packages (from click>=8.0->Flask>=1.0.4->dash==1.19.0) (0.4.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\win\venv\lib\site-packages (from Jinja2>=3.0->Flask>=1.0.4->dash==1.19.0) (2.1.1)
# Installing collected packages: dash-table, dash-html-components, dash-core-components, dash
#   Attempting uninstall: dash-table
#     Found existing installation: dash-table 5.0.0
#     Uninstalling dash-table-5.0.0:
#       Successfully uninstalled dash-table-5.0.0
#   Attempting uninstall: dash-html-components
#     Found existing installation: dash-html-components 2.0.0
#     Uninstalling dash-html-components-2.0.0:
#       Successfully uninstalled dash-html-components-2.0.0
#   Attempting uninstall: dash-core-components
#     Found existing installation: dash-core-components 2.0.0
#     Uninstalling dash-core-components-2.0.0:
#       Successfully uninstalled dash-core-components-2.0.0
#   Attempting uninstall: dash
#     Found existing installation: dash 2.6.0
#     Uninstalling dash-2.6.0:
#       Successfully uninstalled dash-2.6.0
# Successfully installed dash-1.19.0 dash-core-components-1.15.0 dash-html-components-1.1.2 dash-table-4.11.2
# WARNING: You are using pip version 21.3.1; however, version 22.2 is available.
# You should consider upgrading via the 'C:\Users\Win\venv\Scripts\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: jupyter_dash in c:\users\win\venv\lib\site-packages (0.4.2)
# Requirement already satisfied: flask in c:\users\win\venv\lib\site-packages (from jupyter_dash) (2.1.2)
# Requirement already satisfied: nest-asyncio in c:\users\win\venv\lib\site-packages (from jupyter_dash) (1.5.5)
# Requirement already satisfied: requests in c:\users\win\venv\lib\site-packages (from jupyter_dash) (2.27.1)
# Requirement already satisfied: dash in c:\users\win\venv\lib\site-packages (from jupyter_dash) (1.19.0)
# Requirement already satisfied: ansi2html in c:\users\win\venv\lib\site-packages (from jupyter_dash) (1.8.0)
# Requirement already satisfied: ipython in c:\users\win\venv\lib\site-packages (from jupyter_dash) (8.3.0)
# Requirement already satisfied: retrying in c:\users\win\venv\lib\site-packages (from jupyter_dash) (1.3.3)
# Requirement already satisfied: ipykernel in c:\users\win\venv\lib\site-packages (from jupyter_dash) (6.13.0)
# Requirement already satisfied: dash-html-components==1.1.2 in c:\users\win\venv\lib\site-packages (from dash->jupyter_dash) (1.1.2)
# Requirement already satisfied: dash-core-components==1.15.0 in c:\users\win\venv\lib\site-packages (from dash->jupyter_dash) (1.15.0)
# Requirement already satisfied: future in c:\users\win\venv\lib\site-packages (from dash->jupyter_dash) (0.18.2)
# Requirement already satisfied: flask-compress in c:\users\win\venv\lib\site-packages (from dash->jupyter_dash) (1.12)
# Requirement already satisfied: plotly in c:\users\win\venv\lib\site-packages (from dash->jupyter_dash) (5.9.0)
# Requirement already satisfied: dash-renderer==1.9.0 in c:\users\win\venv\lib\site-packages (from dash->jupyter_dash) (1.9.0)
# Requirement already satisfied: dash-table==4.11.2 in c:\users\win\venv\lib\site-packages (from dash->jupyter_dash) (4.11.2)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\win\venv\lib\site-packages (from flask->jupyter_dash) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\win\venv\lib\site-packages (from flask->jupyter_dash) (2.1.2)
# Requirement already satisfied: click>=8.0 in c:\users\win\venv\lib\site-packages (from flask->jupyter_dash) (8.1.3)
# Requirement already satisfied: Werkzeug>=2.0 in c:\users\win\venv\lib\site-packages (from flask->jupyter_dash) (2.0.3)
# Requirement already satisfied: traitlets>=5.1.0 in c:\users\win\venv\lib\site-packages (from ipykernel->jupyter_dash) (5.2.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\win\venv\lib\site-packages (from ipykernel->jupyter_dash) (0.1.3)
# Requirement already satisfied: packaging in c:\users\win\venv\lib\site-packages (from ipykernel->jupyter_dash) (21.3)
# Requirement already satisfied: debugpy>=1.0 in c:\users\win\venv\lib\site-packages (from ipykernel->jupyter_dash) (1.6.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\win\venv\lib\site-packages (from ipykernel->jupyter_dash) (6.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\win\venv\lib\site-packages (from ipykernel->jupyter_dash) (7.3.1)
# Requirement already satisfied: psutil in c:\users\win\venv\lib\site-packages (from ipykernel->jupyter_dash) (5.9.0)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\win\venv\lib\site-packages (from ipython->jupyter_dash) (2.12.0)
# Requirement already satisfied: stack-data in c:\users\win\venv\lib\site-packages (from ipython->jupyter_dash) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\win\venv\lib\site-packages (from ipython->jupyter_dash) (3.0.29)
# Requirement already satisfied: pickleshare in c:\users\win\venv\lib\site-packages (from ipython->jupyter_dash) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in c:\users\win\venv\lib\site-packages (from ipython->jupyter_dash) (0.18.1)
# Requirement already satisfied: colorama in c:\users\win\venv\lib\site-packages (from ipython->jupyter_dash) (0.4.4)
# Requirement already satisfied: setuptools>=18.5 in c:\users\win\venv\lib\site-packages (from ipython->jupyter_dash) (60.2.0)
# Requirement already satisfied: decorator in c:\users\win\venv\lib\site-packages (from ipython->jupyter_dash) (5.1.1)
# Requirement already satisfied: backcall in c:\users\win\venv\lib\site-packages (from ipython->jupyter_dash) (0.2.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\win\venv\lib\site-packages (from requests->jupyter_dash) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\win\venv\lib\site-packages (from requests->jupyter_dash) (2022.5.18.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\win\venv\lib\site-packages (from requests->jupyter_dash) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\win\venv\lib\site-packages (from requests->jupyter_dash) (1.26.9)
# Requirement already satisfied: six>=1.7.0 in c:\users\win\venv\lib\site-packages (from retrying->jupyter_dash) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\win\venv\lib\site-packages (from jedi>=0.16->ipython->jupyter_dash) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\win\venv\lib\site-packages (from Jinja2>=3.0->flask->jupyter_dash) (2.1.1)
# Requirement already satisfied: pyzmq>=22.3 in c:\users\win\venv\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter_dash) (22.3.0)
# Requirement already satisfied: entrypoints in c:\users\win\venv\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter_dash) (0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\win\venv\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter_dash) (2.8.2)
# Requirement already satisfied: jupyter-core>=4.9.2 in c:\users\win\venv\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter_dash) (4.10.0)
# Requirement already satisfied: wcwidth in c:\users\win\venv\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter_dash) (0.2.5)
# Requirement already satisfied: brotli in c:\users\win\venv\lib\site-packages (from flask-compress->dash->jupyter_dash) (1.0.9)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\win\venv\lib\site-packages (from packaging->ipykernel->jupyter_dash) (3.0.8)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\win\venv\lib\site-packages (from plotly->dash->jupyter_dash) (8.0.1)
# Requirement already satisfied: pure-eval in c:\users\win\venv\lib\site-packages (from stack-data->ipython->jupyter_dash) (0.2.2)
# Requirement already satisfied: executing in c:\users\win\venv\lib\site-packages (from stack-data->ipython->jupyter_dash) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\win\venv\lib\site-packages (from stack-data->ipython->jupyter_dash) (2.0.5)
# Requirement already satisfied: pywin32>=1.0 in c:\users\win\venv\lib\site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel->jupyter_dash) (304)
# WARNING: You are using pip version 21.3.1; however, version 22.2 is available.
# You should consider upgrading via the 'C:\Users\Win\venv\Scripts\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: plotly in c:\users\win\venv\lib\site-packages (5.9.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\win\venv\lib\site-packages (from plotly) (8.0.1)
# WARNING: You are using pip version 21.3.1; however, version 22.2 is available.
# You should consider upgrading via the 'C:\Users\Win\venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
from jupyter_dash.comms import _send_jupyter_config_comm_request
_send_jupyter_config_comm_request()

# %%
import pandas as pd

# %%
import dash
import dash_html_components as html
import dash_core_components as dcc
from dash.dependencies import Input, Output
from jupyter_dash import JupyterDash
import plotly.graph_objects as go

# %%
# !pip list
# Out:
# Package              Version
# -------------------- -----------
# ansi2html            1.8.0
# argon2-cffi          21.3.0
# argon2-cffi-bindings 21.2.0
# asttokens            2.0.5
# attrs                21.4.0
# backcall             0.2.0
# beautifulsoup4       4.11.1
# bleach               5.0.0
# Brotli               1.0.9
# certifi              2022.5.18.1
# cffi                 1.15.0
# charset-normalizer   2.0.12
# click                8.1.3
# colorama             0.4.4
# cycler               0.11.0
# dash                 1.19.0
# dash-core-components 1.15.0
# dash-html-components 1.1.2
# dash-renderer        1.9.0
# dash-table           4.11.2
# debugpy              1.6.0
# decorator            5.1.1
# defusedxml           0.7.1
# entrypoints          0.4
# executing            0.8.3
# fastjsonschema       2.15.3
# Flask                2.1.2
# Flask-Compress       1.12
# fonttools            4.33.3
# future               0.18.2
# idna                 3.3
# ipykernel            6.13.0
# ipython              8.3.0
# ipython-genutils     0.2.0
# itsdangerous         2.1.2
# jedi                 0.18.1
# Jinja2               3.1.2
# joblib               1.1.0
# jsonschema           4.5.1
# jupyter-client       7.3.1
# jupyter-core         4.10.0
# jupyter-dash         0.4.2
# jupyterlab-pygments  0.2.2
# kiwisolver           1.4.3
# lxml                 4.9.0
# MarkupSafe           2.1.1
# matplotlib           3.5.2
# matplotlib-inline    0.1.3
# mistune              0.8.4
# nbclient             0.6.3
# nbconvert            6.5.0
# nbformat             5.4.0
# nest-asyncio         1.5.5
# notebook             6.4.11
# numpy                1.22.4
# packaging            21.3
# pandas               1.4.2
# pandas-datareader    0.10.0
# pandocfilters        1.5.0
# parso                0.8.3
# pickleshare          0.7.5
# Pillow               9.1.1
# pip                  21.3.1
# plotly               5.9.0
# prometheus-client    0.14.1
# prompt-toolkit       3.0.29
# psutil               5.9.0
# pure-eval            0.2.2
# pycparser            2.21
# Pygments             2.12.0
# pyparsing            3.0.8
# pyrsistent           0.18.1
# python-dateutil      2.8.2
# pytz                 2022.1
# pywin32              304
# pywinpty             2.0.5
# pyzmq                22.3.0
# requests             2.27.1
# retrying             1.3.3
# scikit-learn         1.1.1
# scipy                1.8.1
# Send2Trash           1.8.0
# setuptools           60.2.0
# six                  1.16.0
# sklearn              0.0
# soupsieve            2.3.2.post1
# stack-data           0.2.0
# tenacity             8.0.1
# terminado            0.13.3
# threadpoolctl        3.1.0
# tinycss2             1.1.1
# tornado              6.1
# traitlets            5.2.0
# urllib3              1.26.9
# wcwidth              0.2.5
# webencodings         0.5.1
# Werkzeug             2.0.3
# wheel                0.37.1
# WARNING: You are using pip version 21.3.1; however, version 22.2 is available.
# You should consider upgrading via the 'C:\Users\Win\venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
spacex_df = pd.read_csv('spacex.csv')

# %%
# skeleton Dash app to be completed in this lab, downloaded from:
# https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/spacex_dash_app.py
# redundant lines commented out

# Import required libraries
# import pandas as pd
# import dash
# import dash_html_components as html
# import dash_core_components as dcc
# from dash.dependencies import Input, Output
import plotly.express as px

# Read the airline data into pandas dataframe
# spacex_df = pd.read_csv("spacex_launch_dash.csv")
max_payload = spacex_df['Payload Mass (kg)'].max()
min_payload = spacex_df['Payload Mass (kg)'].min()

# Create a dash application
# app = dash.Dash(__name__) # commented out as we are using JupyterDash instead of dash.Dash
app = JupyterDash(__name__)

# Create an app layout
app.layout = html.Div(children=[html.H1('SpaceX Launch Records Dashboard',
                                        style={'textAlign': 'center', 'color': '#503D36',
                                               'font-size': 40}),
                                # TASK 1: Add a dropdown list to enable Launch Site selection
                                # The default select value is for ALL sites
                                # dcc.Dropdown(id='site-dropdown',...)
                                dcc.Dropdown(id='site-dropdown',
                                             options=[
                                                     {'label': 'All Sites', 'value': 'ALL'},
                                                     {'label': 'CCAFS LC-40', 'value': 'CCAFS LC-40'},
                                                     {'label': 'VAFB SLC-4E', 'value': 'VAFB SLC-4E'},
                                                     {'label': 'KSC LC-39A', 'value': 'KSC LC-39A'},
                                                     {'label': 'CCAFS SLC-40', 'value': 'CCAFS SLC-40'}
                                                     ],
                                             value='ALL',
                                             placeholder='Select a Launch Site here',
                                             searchable=True
                                             # style={'width':'80%','padding':'3px','font-size':'20px','text-align-last':'center'}
                                             ),
                                html.Br(),

                                # TASK 2: Add a pie chart to show the total successful launches count for all sites
                                # If a specific launch site was selected, show the Success vs. Failed counts for the site
                                html.Div(dcc.Graph(id='success-pie-chart')),
                                html.Br(),

                                html.P("Payload range (Kg):"),
                                # TASK 3: Add a slider to select payload range
                                #dcc.RangeSlider(id='payload-slider',...)
                                dcc.RangeSlider(id='payload-slider',
                                                min=0,
                                                max=10000,
                                                step=1000,
                                                value=[min_payload, max_payload]
                                                ),

                                # TASK 4: Add a scatter chart to show the correlation between payload and launch success
                                html.Div(dcc.Graph(id='success-payload-scatter-chart')),
                                ])

# TASK 2:
# Add a callback function for `site-dropdown` as input, `success-pie-chart` as output
@app.callback(Output(component_id='success-pie-chart', component_property='figure'),
              Input(component_id='site-dropdown', component_property='value'))
def get_pie_chart(entered_site):
    filtered_df = spacex_df
    if entered_site == 'ALL':
        fig = px.pie(filtered_df, values='class', 
        names='Launch Site', 
        title='Success Count for all launch sites')
        return fig
    else:
        # return the outcomes piechart for a selected site
        filtered_df=spacex_df[spacex_df['Launch Site']== entered_site]
        filtered_df=filtered_df.groupby(['Launch Site','class']).size().reset_index(name='class count')
        fig=px.pie(filtered_df,values='class count',names='class',title=f"Total Success Launches for site {entered_site}")
        return fig

# TASK 4:
# Add a callback function for `site-dropdown` and `payload-slider` as inputs, `success-payload-scatter-chart` as output
@app.callback(Output(component_id='success-payload-scatter-chart',component_property='figure'),
                [Input(component_id='site-dropdown',component_property='value'),
                Input(component_id='payload-slider',component_property='value')])
def scatter(entered_site,payload):
    filtered_df = spacex_df[spacex_df['Payload Mass (kg)'].between(payload[0],payload[1])]
    # thought reusing filtered_df may cause issues, but tried it out of curiosity and it seems to be working fine
    
    if entered_site=='ALL':
        fig=px.scatter(filtered_df,x='Payload Mass (kg)',y='class',color='Booster Version Category',title='Success count on Payload mass for all sites')
        return fig
    else:
        fig=px.scatter(filtered_df[filtered_df['Launch Site']==entered_site],x='Payload Mass (kg)',y='class',color='Booster Version Category',title=f"Success count on Payload mass for site {entered_site}")
        return fig

# Run the app
if __name__ == '__main__':
    app.run_server(mode='inline', host='localhost')
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://localhost:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
